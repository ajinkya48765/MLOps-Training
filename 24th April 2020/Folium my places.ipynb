# %%
import folium
import pandas as pd

# %%
dataset =  pd.read_csv("corona cases.csv")

# %%
dataset
# Out:
#         Name of State  Confirmed  Cured  Deaths   Latitude  Longitude
# 0      Andhra Pradesh        955    145      29  14.750429  78.570026
# 1   Arunachal Pradesh          1      1       0  27.100399  93.616601
# 2               Assam         36     19       1  26.244156  92.537842
# 3               Bihar        176     46       2  25.785414  87.479973
# 4        Chhattisgarh         36     28       0  21.295132  81.828232
# 5               Delhi       2376    808      50  28.669993  77.230004
# 6                 Goa          7      7       0  15.491997  73.818001
# 7             Gujarat       2624    258     112  22.309425  72.136230
# 8             Haryana        272    156       3  29.238478  76.431885
# 9    Himachal Pradesh         40     18       1  32.084206  77.571167
# 10  Jammu and Kashmir        427     92       5  34.299959  74.466658
# 11          Jharkhand         55      8       3  23.800393  86.419986
# 12          Karnataka        463    150      18  15.317277  75.713890
# 13             Kerala        448    324       3  10.850516  76.271080
# 14     Madhya Pradesh       1852    203      83  23.473324  77.947998
# 15        Maharashtra       6430    840     283  19.601194  75.552979
# 16            Manipur          2      2       0  24.799971  93.950017
# 17          Meghalaya         12      0       1  25.570492  91.880014
# 18            Mizoram          1      0       0  23.710399  92.720015
# 19             Odisha         90     33       1  20.940920  84.803467
# 20         Puducherry          7      3       0  11.934994  79.830000
# 21             Punjab        277     65      16  31.519974  75.980003
# 22          Rajasthan       1964    230      27  27.391277  73.432617
# 23         Tamil Nadu       1683    752      20  11.059821  78.387451
# 24          Telengana        984    253      26  17.874857  78.100815
# 25            Tripura          2      1       0  23.745127  91.746826
# 26        Uttarakhand         47     24       0  30.320409  78.050006
# 27      Uttar Pradesh       1604    206      24  28.207609  79.826660
# 28        West Bengal        514    103      15  22.978624  87.747803

# %%
dataset.columns
# Out:
# Index(['Name of State', 'Confirmed', 'Cured', 'Deaths', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
positions = dataset[['Latitude','Longitude']]

# %%
#All the coordinates are now in list
positions = positions.values.tolist()

# %%
dataset['Name of State'][1]
# Out:
# 'Arunachal Pradesh'

# %%
myhome = folium.Map(location = [20,78] ,
                    width='100%',
                    height='100%',
                    zoom_start= 5,
                    tiles="Stamen Toner")

# %%
def marker ( i , color):
     folium.Marker(point,
                  icon=folium.Icon(color=color, icon='tint', prefix='fa', icon_color="yellow"),
                     popup=" Confirmed:" + str(dataset['Confirmed'][i]) +"\nDeaths:" + str(dataset['Deaths'][i]) +"\n Recovered:" + str(dataset['Cured'][i]),
                      tooltip=dataset['Name of State'][i]).add_to(myhome)

# %%
i=0
for point in positions :
    if dataset['Confirmed'][i] >= 2000 : 
        marker(i, 'darkred')
    elif dataset['Confirmed'][i] >= 1000 and dataset['Confirmed'][i] < 2000: 
        marker(i, 'red')
    elif dataset['Confirmed'][i] < 1000 and  dataset['Confirmed'][i] >=200 : 
        marker(i, 'orange')
    else :
        marker(i, 'darkgreen')
        
    i+=1

# %%
myhome
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
