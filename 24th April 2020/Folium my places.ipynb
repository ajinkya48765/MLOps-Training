# %%
import folium
import pandas as pd

# %%
dataset =  pd.read_excel("corona cases.xlsx")

# %%
dataset
# Out:
#     S. No. Name of State / UT  Confirmed  Cured  Deaths  Latitude\t  Longitude
# 0      NaN                NaN        NaN    NaN     NaN         NaN        NaN
# 1      1.0     Andhra Pradesh      955.0  145.0    29.0   14.750429  78.570026
# 2      2.0  Arunachal Pradesh        1.0    1.0     0.0   27.100399  93.616601
# 3      3.0              Assam       36.0   19.0     1.0   26.244156  92.537842
# 4      4.0              Bihar      176.0   46.0     2.0   25.785414  87.479973
# 5      5.0       Chhattisgarh       36.0   28.0     0.0   21.295132  81.828232
# 6      6.0              Delhi     2376.0  808.0    50.0   28.669993  77.230004
# 7      7.0                Goa        7.0    7.0     0.0   15.491997  73.818001
# 8      8.0            Gujarat     2624.0  258.0   112.0   22.309425  72.136230
# 9      9.0            Haryana      272.0  156.0     3.0   29.238478  76.431885
# 10    10.0   Himachal Pradesh       40.0   18.0     1.0   32.084206  77.571167
# 11    11.0  Jammu and Kashmir      427.0   92.0     5.0   34.299959  74.466658
# 12    12.0          Jharkhand       55.0    8.0     3.0   23.800393  86.419986
# 13    13.0          Karnataka      463.0  150.0    18.0   15.317277  75.713890
# 14    14.0             Kerala      448.0  324.0     3.0   10.850516  76.271080
# 15    15.0     Madhya Pradesh     1852.0  203.0    83.0   23.473324  77.947998
# 16    16.0        Maharashtra     6430.0  840.0   283.0   19.601194  75.552979
# 17    17.0            Manipur        2.0    2.0     0.0   24.799971  93.950017
# 18    18.0          Meghalaya       12.0    0.0     1.0   25.570492  91.880014
# 19    19.0            Mizoram        1.0    0.0     0.0   23.710399  92.720015
# 20    20.0             Odisha       90.0   33.0     1.0   20.940920  84.803467
# 21    21.0         Puducherry        7.0    3.0     0.0   11.934994  79.830000
# 22    22.0             Punjab      277.0   65.0    16.0   31.519974  75.980003
# 23    23.0          Rajasthan     1964.0  230.0    27.0   27.391277  73.432617
# 24    24.0         Tamil Nadu     1683.0  752.0    20.0   11.059821  78.387451
# 25    25.0          Telengana      984.0  253.0    26.0   17.874857  78.100815
# 26    26.0            Tripura        2.0    1.0     0.0   23.745127  91.746826
# 27    27.0        Uttarakhand       47.0   24.0     0.0   30.320409  78.050006
# 28    28.0      Uttar Pradesh     1604.0  206.0    24.0   28.207609  79.826660
# 29    29.0        West Bengal      514.0  103.0    15.0   22.978624  87.747803

# %%
myhome = folium.Map(location = [19.063103, 74.764315] ,
                    width='50%',
                    height='50%',
                    zoom_start= 13,
                    tiles="Stamen Toner")

folium.Marker([19.063103, 74.764315], icon=folium.Icon(color='green', icon='tint', prefix='fa',icon_color="yellow")).add_to(myhome)

# %%
myhome
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
